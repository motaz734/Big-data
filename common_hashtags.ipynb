# %%
import pandas as pd

# %%
df = pd.read_csv("tweets.csv")

# %%
df.head()
# Out:
#                     id      conversation_id  \
# 0  1515345123105980422  1515293448685113351
# 1  1515345108421554184  1515345108421554184
# 2  1515345102662942720  1515345102662942720
# 3  1515345071922728962  1515339060524498945
# 4  1515345067514335239  1515345067514335239
#
#                                 created_at        date      time  timezone  \
# 0  2022-04-16 17:03:25 Egypt Standard Time  2022-04-16  17:03:25       200
# 1  2022-04-16 17:03:22 Egypt Standard Time  2022-04-16  17:03:22       200
# 2  2022-04-16 17:03:20 Egypt Standard Time  2022-04-16  17:03:20       200
# 3  2022-04-16 17:03:13 Egypt Standard Time  2022-04-16  17:03:13       200
# 4  2022-04-16 17:03:12 Egypt Standard Time  2022-04-16  17:03:12       200
#
#                user_id         username                name place  ... geo  \
# 0           4863154803      shajhanxp35       Shajhan Ahmed   NaN  ... NaN
# 1            344657887        tha_given          🌻Keneilwe👽   NaN  ... NaN
# ...

# %%
import numpy as np
df_hashtags = df['hashtags'].str.split(',', expand=True)
df_hashtags = df_hashtags.replace('[]', np.nan)
df_hashtags = df_hashtags.replace(r'[\[\]]', '', regex=True)

# %%
df_hashtags.dropna(how='all', inplace=True)
df_hashtags
# Out:
#                           0                1                       2   \
# 0                'hyperwalk'     'movetoearn'         'collecttoearn'
# 12     'lifeofterrytreasure'             None                    None
# 16                'poshmark'   'shopmycloset'                    None
# 18                'premiata'             'ad'                 'スニーカー'
# 20                    'veja'             'ad'                  '스니커즈'
# ...                      ...              ...                     ...
# 22380               'jordan'       'sneakers'           'sneakerhead'
# 22381          'sneakerhead'       'sneakers'   'betterlatethannever'
# 22384             'sneakers'             None                    None
# 22393             'poshmark'   'shopmycloset'                    None
# 22405             'sneakers'           'nike'                    None
#
#                3           4            5              6              7   \
# ...

# %%
df_comb = pd.DataFrame()
temp = []
val_count_tmp = pd.Series(dtype=float)

# sum all df_hashtags in dataframe with iteration
for col in df_hashtags.columns:
    temp.append(df_hashtags[col].fillna(0).value_counts())

for val_count in temp:
    val_count_tmp = val_count_tmp.add(val_count,fill_value=0)

y = val_count_tmp.dropna().drop(0)
y.sort_values(ascending=False, inplace=True)

y = y[y>50]

y.head(10).append(y.tail(10))
# Out:
# C:\Users\ymg59\AppData\Local\Temp\ipykernel_10164\4049173881.py:17: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   y.head(10).append(y.tail(10))
# 'poshmark'         663.0
#  'shopmycloset'    662.0
#  'nike'            419.0
#  'adidas'          412.0
#  'fashion'         405.0
#  'style'           387.0
# 'nike'             216.0
#  'sneakers'        209.0
# 'adidas'           193.0
# 'ebay'             134.0
#  'ad'              100.0
#  'snkrs'            95.0
#  'sneakerhead'      77.0
# 'sneakers'          73.0
#  'jordan'           69.0
#  'スニーカー'            61.0
# 'rakuafl'           57.0
#  'tour360'          57.0
# 'rakutenichiba'     57.0
#  'ナイキ'              51.0
# dtype: float64

# %%
y.plot.bar(figsize=(200,100), fontsize=150)
# Out:
# <AxesSubplot:>
# C:\Users\ymg59\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 12473 (\N{KATAKANA LETTER SU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\ymg59\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 12491 (\N{KATAKANA LETTER NI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\ymg59\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 12540 (\N{KATAKANA-HIRAGANA PROLONGED SOUND MARK}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\ymg59\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 12459 (\N{KATAKANA LETTER KA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...
